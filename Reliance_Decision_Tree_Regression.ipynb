# %% [markdown]
# <a href="https://colab.research.google.com/github/vafiyanaznin/Linear-regresssion-in-Machine-learning/blob/main/Reliance_Decision_Tree_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('RELIANCE.NS.csv')

# %%
x = dataset.iloc[:, :-1].values

# %%
y = dataset.iloc[:, -1].values

# %%
y = y.reshape(len(y),1)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = regressor.predict(x)

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.xlabel('Open')
plt.ylabel('Date')
plt.show()
